# %%
# https://huggingface.co/pysentimiento/robertuito-sentiment-analysis

from transformers import pipeline

# 1. Cargamos un pipeline de análisis de sentimiento
# Este modelo es multilingüe y funciona excelente con español
classifier = pipeline("sentiment-analysis", model="pysentimiento/robertuito-sentiment-analysis")

# 2. Definimos nuestras reseñas sobre el arroz
comentarios = [
    "El grano de arroz está excelente, muy blanco y con gran textura.",
    "Estoy muy decepcionado, el producto llegó con muchas impurezas y restos de cascarilla.",
    "El arroz es aceptable, el sabor es estándar.",
    "Excelente uniformidad y color cristalino.",
    "El grano presenta alto porcentaje de yesado.",
    "Mucho contenido de granos rotos en el empaque.",
    "El arroz tiene una calidad excelente muy blanco.",
    "Sabor neutro y buena cocción.",
    "Demasiadas impurezas y restos de cascarilla.",
    "Muy buena apariencia y color claro.",
    "Muy mala apariencia y color obscuro.",
    "Los granos presentan impurezas y mal olor.",
    "Muy buen sabor y consistencia del grano.",
]

# 3. Clasificación
for c in comentarios:
    resultado = classifier(c)
    print(f"Texto: {c}")
    print(f"Sentimiento: {resultado[0]['label']}, Confianza: {resultado[0]['score']:.2f}\n")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Texto: El grano de arroz está excelente, muy blanco y con gran textura.
# Sentimiento: POS, Confianza: 0.98
#
# Texto: Estoy muy decepcionado, el producto llegó con muchas impurezas y restos de cascarilla.
# Sentimiento: NEG, Confianza: 0.99
#
# Texto: El arroz es aceptable, el sabor es estándar.
# Sentimiento: POS, Confianza: 0.58
#
# Texto: Excelente uniformidad y color cristalino.
# Sentimiento: POS, Confianza: 0.94
#
# Texto: El grano presenta alto porcentaje de yesado.
# Sentimiento: NEU, Confianza: 0.62
#
# Texto: Mucho contenido de granos rotos en el empaque.
# Sentimiento: NEG, Confianza: 0.89
#
# Texto: El arroz tiene una calidad excelente muy blanco.
# Sentimiento: POS, Confianza: 0.97
#
# Texto: Sabor neutro y buena cocción.
# Sentimiento: POS, Confianza: 0.84
#
# Texto: Demasiadas impurezas y restos de cascarilla.
# Sentimiento: NEG, Confianza: 0.82
#
# Texto: Muy buena apariencia y color claro.
# Sentimiento: POS, Confianza: 0.97
#
# Texto: Muy mala apariencia y color obscuro.
# Sentimiento: NEG, Confianza: 0.93
#
# Texto: Los granos presentan impurezas y mal olor.
# Sentimiento: NEG, Confianza: 0.96
#
# Texto: Muy buen sabor y consistencia del grano.
# Sentimiento: POS, Confianza: 0.97
