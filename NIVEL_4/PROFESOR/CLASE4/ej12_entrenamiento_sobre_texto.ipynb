# %%
from transformers import pipeline

# Cargar un modelo directamente desde Hugging Face
generator = pipeline("text-generation", model="mistralai/Mistral-7B-v0.1")
prompt = "¿Cuál es el procedimiento de inspección de grano de arroz?"
response = generator(prompt, max_length=100)
print(response)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_479/635820642.py in <cell line: 0>()
#       2
#       3 # Cargar un modelo directamente desde Hugging Face
# ----> 4 generator = pipeline("text-generation", model="mistralai/Mistral-7B-v0.1")
#       5 prompt = "¿Cuál es el procedimiento de inspección de grano de arroz?"
#       6 response = generator(prompt, max_length=100)
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1122         kwargs["processor"] = processor
#    1123
# -> 1124     return pipeline_class(model=model, task=task, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_generation.py in __init__(self, *args, **kwargs)
#      98
#      99     def __init__(self, *args, **kwargs):
# --> 100         super().__init__(*args, **kwargs)
#     101         self.check_model_type(MODEL_FOR_CAUSAL_LM_MAPPING_NAMES)
#     102         # Decoder-only models require left-padding for correct batched generation.
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in __init__(self, model, tokenizer, feature_extractor, image_processor, video_processor, processor, task, device, binary_output, **kwargs)
#     864             and hf_device_map is None
#     865         ):
# --> 866             self.model.to(self.device)
#     867
#     868         # If it's a generation pipeline and the model can generate:
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    3727                     " `dtype` by passing the correct `dtype` argument."
#    3728                 )
# -> 3729         return super().to(*args, **kwargs)
#    3730
#    3731     def half(self, *args):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1382                     raise
#    1383
# -> 1384         return self._apply(convert)
#    1385
#    1386     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     932         if recurse:
#     933             for module in self.children():
# --> 934                 module._apply(fn)
#     935
#     936         from torch._subclasses.fake_tensor import FakeTensor
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     932         if recurse:
#     933             for module in self.children():
# --> 934                 module._apply(fn)
#     935
#     936         from torch._subclasses.fake_tensor import FakeTensor
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     963             # `with torch.no_grad():`
#     964             with torch.no_grad():
# --> 965                 param_applied = fn(param)
#     966             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     967
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in convert(t)
#    1368                         memory_format=convert_to_format,
#    1369                     )
# -> 1370                 return t.to(
#    1371                     device,
#    1372                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 250.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 65.81 MiB is free. Including non-PyTorch memory, this process has 14.50 GiB memory in use. Of the allocated memory 14.23 GiB is allocated by PyTorch, and 149.35 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
